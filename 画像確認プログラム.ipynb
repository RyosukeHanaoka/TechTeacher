# %% [markdown]
# <a href="https://colab.research.google.com/github/RyosukeHanaoka/TechTeacher/blob/main/%E7%94%BB%E5%83%8F%E7%A2%BA%E8%AA%8D%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydicom
# !pip install pylibjpeg
# !pip install python-gdcm
# !pip install pylibjpeg-libjpeg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 11.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
import os
import shutil
import pydicom
import cv2
import numpy as np

# %%
import matplotlib.pyplot as plt
ds="/content/drive/MyDrive/xpFiles_Hand_copy/000067_1.2.392.200036.9107.307.13535.1353519020215409.121.dcm"
file=pydicom.dcmread(ds)
image =file.pixel_array
plt.imshow(image)
plt.show()
