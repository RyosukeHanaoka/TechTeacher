# %%
# !pip install pydicom
# !pip install pylibjpeg
# !pip install python-gdcm
# !pip install pylibjpeg-libjpeg
# !pip install pillow as PIL
# Out:
# Collecting pydicom
#   Downloading pydicom-2.4.2-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.1 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.4.2
# Collecting pylibjpeg
#   Downloading pylibjpeg-1.4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pylibjpeg) (1.22.4)
# Installing collected packages: pylibjpeg
# Successfully installed pylibjpeg-1.4.0
# Collecting python-gdcm
#   Downloading python_gdcm-3.0.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 93.9 MB/s eta 0:00:00
# Installing collected packages: python-gdcm
# Successfully installed python-gdcm-3.0.22
# Collecting pylibjpeg-libjpeg
#   Downloading pylibjpeg_libjpeg-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from pylibjpeg-libjpeg) (1.22.4)
# Installing collected packages: pylibjpeg-libjpeg
# Successfully installed pylibjpeg-libjpeg-1.3.4
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
# まず、使用するライブラリを呼び出す。
from google.colab import drive
import os
import shutil
import pydicom
import cv2
import numpy as np

# %%
# Google Driveを呼び出す。
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# xpFilesのコピーを作成する。
shutil.copytree('/content/drive/MyDrive/xpFiles','/content/drive/MyDrive/xpFiles_copy')

# %%
for root, dirs, files in os.walk('/content/drive/MyDrive/xpFiles_copy'):# '/content/drive/MyDrive/xpFiles_copy'の中のroot、directory、fileを走査する。
    for file in files:
        # 変数patient_idを定義
        patient_id = os.path.dirname(root)[40:46]
        # 変数patient_filename_taleを定義
        patient_filename_tale = os.path.basename(root)
        # 変数new_filenameを定義
        file_extension = os.path.splitext(file)[1]  # 元のファイルの拡張子を取得
        new_filename = patient_id+'_'+ patient_filename_tale+".dcm"
        os.rename(os.path.join(root, file), os.path.join(root, new_filename))

# %%
# xpFiles_copyのコピーを作成する。
shutil.copytree('/content/drive/MyDrive/xpFiles_copy','/content/drive/MyDrive/xpFiles_copy_of_copy')
# Out:
# '/content/drive/MyDrive/xpFiles_copy_of_copy'

# %%
os.makedirs('/content/drive/MyDrive/xpFiles_Hand', exist_ok=True)

for root, dirs, files in os.walk('/content/drive/MyDrive/xpFiles_copy_of_copy'):
    for file in files:
        dcmfile_path = os.path.join(root, file)
        ds = pydicom.dcmread(dcmfile_path, force=True)

        if hasattr(ds, 'BodyPartExamined'):
            body_part = ds.BodyPartExamined
            if body_part == 'HAND':
                shutil.move(dcmfile_path, '/content/drive/MyDrive/xpFiles_Hand')

# %%
#xpFiles_Handのコピーを作成する。
shutil.copytree('/content/drive/MyDrive/xpFiles_Hand','/content/drive/MyDrive/xpFiles_Hand_copy')
# Out:
# '/content/drive/MyDrive/xpFiles_Hand_copy'

# %%
import numpy as np
import pydicom
import pylibjpeg
from PIL import Image
import os

# %%
# DICOMファイルをPNGファイルに変換
def dicom_to_png(dcmfile_path):
    try:
        ds = pydicom.dcmread(dcmfile_path)  # dicomファイルのメタデータを変数dsに代入。
        img = ds.pixel_array * ds.RescaleSlope + ds.RescaleIntercept  # 画像データをNumPyのndarrayとして取得したものと、変数imgにDICOMタグの(0028,1052)とDICOMタグの(0028,1052)を加えたものをかける。
        img = np.clip((img - (ds.WindowCenter - 0.5)) / (ds.WindowWidth - 0.5 + np.spacing(1)) * 255, 0, 255)  # 画像のウインドニングを行う計算式
        pngfile_path = dcmfile_path.replace('.dcm', '.png')  # 拡張子の変更
        cv2.imwrite(pngfile_path, img.astype(np.uint8))
    except RuntimeError as e:
        print(f"An error occurred while processing {dcmfile_path}: {str(e)}")
        # このファイルはスキップして次に進みます

for root, dirs, files in os.walk('/content/drive/MyDrive/xpFiles_Hand'):
    for file in files:
        dcmfile_path = os.path.join(root, file)
        dicom_to_png(dcmfile_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0e32a2b639f6> in <cell line: 13>()
#      14     for file in files:
#      15         dcmfile_path = os.path.join(root, file)
# ---> 16         dicom_to_png(dcmfile_path)
#
# <ipython-input-4-0e32a2b639f6> in dicom_to_png(dcmfile_path)
#       3     try:
#       4         ds = pydicom.dcmread(dcmfile_path)  # dicomファイルのメタデータを変数dsに代入。
# ----> 5         img = ds.pixel_array * ds.RescaleSlope + ds.RescaleIntercept  # 画像データをNumPyのndarrayとして取得したものと、変数imgにDICOMタグの(0028,1052)とDICOMタグの(0028,1052)を加えたものをかける。
#       6         img = np.clip((img - (ds.WindowCenter - 0.5)) / (ds.WindowWidth - 0.5 + np.spacing(1)) * 255, 0, 255)  # 画像のウインドニングを行う計算式
#       7         pngfile_path = dcmfile_path.replace('.dcm', '.png')  # 拡張子の変更
#
# /usr/local/lib/python3.10/dist-packages/pydicom/dataset.py in __getattr__(self, name)
#     906             return {}
#     907         # Try the base class attribute getter (fix for issue 332)
# --> 908         return object.__getattribute__(self, name)
#     909
#     910     @property
#
# AttributeError: 'FileDataset' object has no attribute 'RescaleSlope'

# %%
def dicom_to_png(dcmfile_path):
    try:
        ds = pydicom.dcmread(dcmfile_path)  # dicomファイルのメタデータを変数dsに代入。
        rescale_slope = 1  # デフォルト値を1に設定
        rescale_intercept = 0  # デフォルト値を0に設定

        if 'RescaleSlope' in ds:
            rescale_slope = ds.RescaleSlope
        if 'RescaleIntercept' in ds:
            rescale_intercept = ds.RescaleIntercept

        img = ds.pixel_array * rescale_slope + rescale_intercept
        img = np.clip((img - (ds.WindowCenter - 0.5)) / (ds.WindowWidth - 0.5 + np.spacing(1)) * 255, 0, 255)  # 画像のウインドニングを行う計算式
        pngfile_path = dcmfile_path.replace('.dcm', '.png')  # 拡張子の変更
        cv2.imwrite(pngfile_path, img.astype(np.uint8))
    except RuntimeError as e:
        print(f"An error occurred while processing {dcmfile_path}: {str(e)}")
        # このファイルはスキップして次に進みます

for root, dirs, files in os.walk('/content/drive/MyDrive/xpFiles_Hand'):
    for file in files:
        dcmfile_path = os.path.join(root, file)
        dicom_to_png(dcmfile_path)

# %%
def dicom_to_png(dcmfile_path, png_directory):
    try:
        ds = pydicom.dcmread(dcmfile_path)  # dicomファイルのメタデータを変数dsに代入。
        rescale_slope = 1  # デフォルト値を1に設定
        rescale_intercept = 0  # デフォルト値を0に設定

        if 'RescaleSlope' in ds:
            rescale_slope = ds.RescaleSlope
        if 'RescaleIntercept' in ds:
            rescale_intercept = ds.RescaleIntercept

        img = ds.pixel_array * rescale_slope + rescale_intercept
        img = np.clip((img - (ds.WindowCenter - 0.5)) / (ds.WindowWidth - 0.5 + np.spacing(1)) * 255, 0, 255)
        pngfile_path = dcmfile_path.replace('.dcm', '.png')  # 拡張子の変更
        cv2.imwrite(pngfile_path, img.astype(np.uint8))
    except RuntimeError as e:
        print(f"An error occurred while processing {dcmfile_path}: {str(e)}")

png_directory = '/content/drive/MyDrive/xpFiles_PNG'

# 必要であれば、ディレクトリを作成します。
os.makedirs(png_directory, exist_ok=True)

for root, dirs, files in os.walk('/content/drive/MyDrive/xpFiles_Hand'):
    for file in files:
        dcmfile_path = os.path.join(root, file)
        dicom_to_png(dcmfile_path, png_directory)
# Out:
# ---------------------------------------------------------------------------
# InvalidDicomError                         Traceback (most recent call last)
# <ipython-input-6-4de14b1d32e7> in <cell line: 24>()
#      25     for file in files:
#      26         dcmfile_path = os.path.join(root, file)
# ---> 27         dicom_to_png(dcmfile_path, png_directory)
#
# <ipython-input-6-4de14b1d32e7> in dicom_to_png(dcmfile_path, png_directory)
#       1 def dicom_to_png(dcmfile_path, png_directory):
#       2     try:
# ----> 3         ds = pydicom.dcmread(dcmfile_path)  # dicomファイルのメタデータを変数dsに代入。
#       4         rescale_slope = 1  # デフォルト値を1に設定
#       5         rescale_intercept = 0  # デフォルト値を0に設定
#
# /usr/local/lib/python3.10/dist-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1028         stop_when = _at_pixel_data
#    1029     try:
# -> 1030         dataset = read_partial(
#    1031             fp,
#    1032             stop_when,
#
# /usr/local/lib/python3.10/dist-packages/pydicom/filereader.py in read_partial(fileobj, stop_when, defer_size, force, specific_tags)
#     776
#     777     # Read preamble (if present)
# --> 778     preamble = read_preamble(fileobj, force)
#     779     # Read any File Meta Information group (0002,eeee) elements (if present)
#     780     file_meta = _read_file_meta_info(fileobj)
#
# /usr/local/lib/python3.10/dist-packages/pydicom/filereader.py in read_preamble(fp, force)
#     721
#     722     if magic != b"DICM" and not force:
# --> 723         raise InvalidDicomError(
#     724             "File is missing DICOM File Meta Information header or the 'DICM' "
#     725             "prefix is missing from the header. Use force=True to force "
#
# InvalidDicomError: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
